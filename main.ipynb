# %%
from db import get_engine, register_magic, run_sql

engine = get_engine()            # create once (or rely on .env)
register_magic(engine)
# Out:
# Engine(mysql+mysqlconnector://root:***@127.0.0.1:3306/sql_practice)

# %%
# %%runsql
# SELECT * FROM order_items;
# Out:
# order_item_id | order_id | product_id | quantity | unit_price
# --------------+----------+------------+----------+-----------
# 1             | 1001     | 101        | 1        | 1299.99
# 2             | 1001     | 103        | 1        | 12.99
# 3             | 1001     | 102        | 1        | 29.99
# 4             | 1002     | 102        | 1        | 29.99
# 5             | 1003     | 107        | 2        | 89.99
# 6             | 1003     | 108        | 2        | 349.99
# 7             | 1003     | 103        | 1        | 12.99
# 8             | 1004     | 110        | 1        | 45.99
# 9             | 1005     | 108        | 1        | 349.99
# 10            | 1005     | 102        | 1        | 29.99
# 11            | 1006     | 101        | 1        | 1299.99
# 12            | 1007     | 107        | 1        | 89.99
# 13            | 1007     | 103        | 1        | 12.99
# 14            | 1008     | 106        | 1        | 599.99
# 15            | 1009     | 108        | 1        | 349.99
# 16            | 1010     | 107        | 1        | 89.99
# 17            | 1011     | 101        | 1        | 1299.99
# 18            | 1011     | 108        | 1        | 349.99
# 19            | 1011     | 102        | 3        | 29.99
# 20            | 1012     | 105        | 1        | 299.99
# 21            | 1013     | 109        | 1        | 79.99
# 22            | 1014     | 103        | 1        | 12.99
# 23            | 1015     | 108        | 2        | 349.99
# 24            | 1015     | 107        | 1        | 89.99
# 25            | 1015     | 102        | 1        | 29.99

# %%
# %%runsql
# SELECT * FROM products;
# Out:
# product_id | product_name        | category    | price   | stock_quantity | supplier_id | last_updated
# -----------+---------------------+-------------+---------+----------------+-------------+-------------
# 101        | Laptop Pro 15"      | Electronics | 1299.99 | 45             | 1           | 2024-01-15
# 102        | wireless mouse      | electronics | 29.99   | 150            | 1           | 2024-01-20
# 103        | USB-C Cable         | Accessories | 12.99   | 200            | 2           | 2024-02-01
# 104        | Laptop Pro 15"      | Electronics | 1299.99 | 30             | 1           | 2024-02-10
# 105        | Office Chair        | Furniture   | 299.99  | 25             | 3           | 2024-01-25
# 106        | Standing Desk       | furniture   | 599.99  | 15             | 3           | 2024-02-05
# 107        | Keyboard Mechanical | Electronics | 89.99   | 80             | 1           | 2024-01-30
# 108        | Monitor 27"         | Electronics | 349.99  | 40             | 1           | 2024-02-15
# 109        | Webcam HD           | Electronics | 79.99   |                | 2           | 2024-01-18
# 110        | Desk Lamp           | Furniture   | 45.99   | 60             | 3           | 2024-02-20
# 111        | Notebook Pack       | Stationery  | 15.99   | 300            | 4           | 2024-01-22
# 112        | Pen Set             | stationery  | 8.99    | 250            | 4           | 2024-02-08
