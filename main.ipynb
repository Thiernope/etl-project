# %%
from db import get_engine, register_magic, run_sql

engine = get_engine()            # create once (or rely on .env)
register_magic(engine)
# Out:
# Engine(mysql+mysqlconnector://root:***@127.0.0.1:3306/Parks_and_Recreation)

# %%
# %%runsql
# SELECT * FROM employee_demographics
# ;
# Out:
# employee_id | first_name | last_name    | age | gender | birth_date
# ------------+------------+--------------+-----+--------+-----------
# 1           | Leslie     | Knope        | 44  | Female | 1979-09-25
# 3           | Tom        | Haverford    | 36  | Male   | 1987-03-04
# 4           | April      | Ludgate      | 29  | Female | 1994-03-27
# 5           | Jerry      | Gergich      | 61  | Male   | 1962-08-28
# 6           | Donna      | Meagle       | 46  | Female | 1977-07-30
# 7           | Ann        | Perkins      | 35  | Female | 1988-12-01
# 8           | Chris      | Traeger      | 43  | Male   | 1980-11-11
# 9           | Ben        | Wyatt        | 38  | Male   | 1985-07-26
# 10          | Andy       | Dwyer        | 34  | Male   | 1989-03-25
# 11          | Mark       | Brendanawicz | 40  | Male   | 1983-06-14
# 12          | Craig      | Middlebrooks | 37  | Male   | 1986-07-27

# %%
# %%runsql
# SELECT *
# FROM employee_salary
# ;
# Out:
# employee_id | first_name | last_name    | occupation                                        | salary | dept_id
# ------------+------------+--------------+---------------------------------------------------+--------+--------
# 1           | Leslie     | Knope        | Deputy Director of Parks and Recreation           | 75000  | 1
# 2           | Ron        | Swanson      | Director of Parks and Recreation                  | 70000  | 1
# 3           | Tom        | Haverford    | Entrepreneur                                      | 50000  | 1
# 4           | April      | Ludgate      | Assistant to the Director of Parks and Recreation | 25000  | 1
# 5           | Jerry      | Gergich      | Office Manager                                    | 50000  | 1
# 6           | Donna      | Meagle       | Office Manager                                    | 60000  | 1
# 7           | Ann        | Perkins      | Nurse                                             | 55000  | 4
# ...

# %%
# %%runsql
# SELECT *
# FROM parks_departments
# ;
# Out:
# department_id | department_name
# --------------+---------------------
# 1             | Parks and Recreation
# 2             | Animal Control
# 3             | Public Works
# 4             | Healthcare
# 5             | Library
# 6             | Finance

# %%
# %%runsql
# SELECT *
# FROM employee_demographics
# WHERE employee_id IN (
#     SELECT employee_id
#      FROM employee_salary
#     WHERE dept_id = 3
# )
# Out:
# employee_id | first_name | last_name    | age | gender | birth_date
# ------------+------------+--------------+-----+--------+-----------
# 8           | Chris      | Traeger      | 43  | Male   | 1980-11-11
# 11          | Mark       | Brendanawicz | 40  | Male   | 1983-06-14

# %%
# %%runsql
# SELECT first_name,
# last_name,
# occupation,
# salary,
# (
#  SELECT AVG(salary)
#   FROM employee_salary
# ) AS av_salary_for_all_employees,
# dept_id
# FROM employee_salary
# WHERE salary > (
#  SELECT AVG(salary)
#   FROM employee_salary
# )
# ;
# Out:
# first_name | last_name    | occupation                              | salary | av_salary_for_all_employees | dept_id
# -----------+--------------+-----------------------------------------+--------+-----------------------------+--------
# Leslie     | Knope        | Deputy Director of Parks and Recreation | 75000  | 57250.0000                  | 1
# Ron        | Swanson      | Director of Parks and Recreation        | 70000  | 57250.0000                  | 1
# Donna      | Meagle       | Office Manager                          | 60000  | 57250.0000                  | 1
# Chris      | Traeger      | City Manager                            | 90000  | 57250.0000                  | 3
# Ben        | Wyatt        | State Auditor                           | 70000  | 57250.0000                  | 6
# Craig      | Middlebrooks | Parks Director                          | 65000  | 57250.0000                  | 1

# %%
# %%runsql
# select * from employee_demographics;
# Out:
# employee_id | first_name | last_name    | age | gender | birth_date
# ------------+------------+--------------+-----+--------+-----------
# 1           | Leslie     | Knope        | 44  | Female | 1979-09-25
# 3           | Tom        | Haverford    | 36  | Male   | 1987-03-04
# 4           | April      | Ludgate      | 29  | Female | 1994-03-27
# 5           | Jerry      | Gergich      | 61  | Male   | 1962-08-28
# 6           | Donna      | Meagle       | 46  | Female | 1977-07-30
# 7           | Ann        | Perkins      | 35  | Female | 1988-12-01
# 8           | Chris      | Traeger      | 43  | Male   | 1980-11-11
# 9           | Ben        | Wyatt        | 38  | Male   | 1985-07-26
# 10          | Andy       | Dwyer        | 34  | Male   | 1989-03-25
# 11          | Mark       | Brendanawicz | 40  | Male   | 1983-06-14
# 12          | Craig      | Middlebrooks | 37  | Male   | 1986-07-27

# %%
# %%runsql
# select gender,
# avg(age) as av_age
# from employee_demographics
# group by gender
# order by av_age DESC
# limit 1
# ;
# Out:
# gender | av_age
# -------+--------
# Male   | 41.2857

# %%
# %%runsql
# select occupation,
# avg(av_salary)
# from(
# select occupation,
# avg(salary) as av_salary
# from employee_salary
# group by occupation
# ) as agg_av_salary_for_every_occupation
# group by occupation
# ;
# Out:
# occupation                                        | avg(av_salary)
# --------------------------------------------------+---------------
# Deputy Director of Parks and Recreation           | 75000.00000000
# Director of Parks and Recreation                  | 70000.00000000
# Entrepreneur                                      | 50000.00000000
# Assistant to the Director of Parks and Recreation | 25000.00000000
# Office Manager                                    | 55000.00000000
# Nurse                                             | 55000.00000000
# City Manager                                      | 90000.00000000
# State Auditor                                     | 70000.00000000
# Shoe Shiner and Musician                          | 20000.00000000
# City Planner                                      | 57000.00000000
# Parks Director                                    | 65000.00000000

# %%
# %%runsql
# select *
# from employee_demographics as dem
# join employee_salary as sal
#     on dem.employee_id = sal.employee_id
# Out:
# employee_id | first_name | last_name    | age | gender | birth_date | employee_id | first_name | last_name    | occupation                                        | salary | dept_id
# ------------+------------+--------------+-----+--------+------------+-------------+------------+--------------+---------------------------------------------------+--------+--------
# 1           | Leslie     | Knope        | 44  | Female | 1979-09-25 | 1           | Leslie     | Knope        | Deputy Director of Parks and Recreation           | 75000  | 1
# 3           | Tom        | Haverford    | 36  | Male   | 1987-03-04 | 3           | Tom        | Haverford    | Entrepreneur                                      | 50000  | 1
# 4           | April      | Ludgate      | 29  | Female | 1994-03-27 | 4           | April      | Ludgate      | Assistant to the Director of Parks and Recreation | 25000  | 1
# ...

# %%
# %%runsql
# select dem.employee_id,
# dem.first_name,
# dem.last_name,
# dem.gender,
# salary,
# SUM(salary) OVER(PARTITION BY gender order by dem.employee_id) AS sum,
# ((salary * 100) / SUM(salary) OVER(PARTITION BY gender)) as percentage
# from employee_demographics as dem
# join employee_salary as sal
#     on dem.employee_id = sal.employee_id
# ;
# Out:
# employee_id | first_name | last_name    | gender | salary | sum    | percentage
# ------------+------------+--------------+--------+--------+--------+-----------
# 1           | Leslie     | Knope        | Female | 75000  | 75000  | 34.8837
# 4           | April      | Ludgate      | Female | 25000  | 100000 | 11.6279
# 6           | Donna      | Meagle       | Female | 60000  | 160000 | 27.9070
# 7           | Ann        | Perkins      | Female | 55000  | 215000 | 25.5814
# 3           | Tom        | Haverford    | Male   | 50000  | 50000  | 12.4378
# 5           | Jerry      | Gergich      | Male   | 50000  | 100000 | 12.4378
# 8           | Chris      | Traeger      | Male   | 90000  | 190000 | 22.3881
# 9           | Ben        | Wyatt        | Male   | 70000  | 260000 | 17.4129
# 10          | Andy       | Dwyer        | Male   | 20000  | 280000 | 4.9751
# 11          | Mark       | Brendanawicz | Male   | 57000  | 337000 | 14.1791
# ...
